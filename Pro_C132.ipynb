# %% [markdown]
# <a href="https://colab.research.google.com/github/Darksoul913/Pro-C132/blob/main/Pro_C132.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("gravity.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 0.1  Unnamed: 0.1.1      star_names     distance  \
# 0           0            0               0             Sun  0.000015813
# 1           1            1               1          Sirius       0008.6
# 2           2            2               2         Canopus         0310
# 3           3            3               3  Alpha Centauri       0004.4
# 4           4            4               4        Arcturus         0037
#
#      mass  radius luminosity  solar_mass  solar_radius apparent_magintude  \
# 0       1    1.00          1    0.000955      0.102763        0.000−26.74
# 1    25.4    1.71       25.4    0.024247      0.000000         0.001−1.46
# 2  13,500   71.00      13500    0.000000      7.296173         0.003−0.74
# 3       2    1.20          2    0.001909      0.123316         0.004−0.27
# 4     170   26.00        170    0.162280      2.671838         0.005−0.05
#
#              star_gravity
# 0                       0
# 1                     0.0
# ...

# %%
mass = df["mass"].to_list()
radius = df["radius"].to_list()
dist = df["distance"].to_list()
gravity = df["star_gravity"].to_list()

# %%
mass.sort()
radius.sort()
gravity.sort()
plt.plot(radius,mass)


plt.title("Radius & Mass of the Star")
plt.xlabel("Radius")
plt.ylabel("Mass")
plt.show()

# %%
plt.plot(mass,gravity)

plt.title("Mass vs Gravity")
plt.xlabel("Mass")
plt.ylabel("Gravity")
plt.show()
